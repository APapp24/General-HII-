# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7deecc485a4> in <module>()
#       3 T = 5.78
#       4 # flux(20, 50)
# ----> 5 print("recomb 10 and 50: ", recomb_rate(10), recomb_rate(50))
#       6 print("flux lower and upper: ", flux(7, 10), flux(10, 50))
#
# NameError: name 'recomb_rate' is not defined

# %%
import math
import numpy as np

def flux(r, T):
    return 3.85 * 10**41 * r**2 * (2.46* 10**4 * T + 1.57 * 100 * T**2 + 2 * T**3) * math.e**(-1.57 * 100 / T)

def recomb_rate(T):
    return 8.2 * 10**(-14) * T**(-0.8)

def stromgren(T, T_e, r, n):
    return 0.62 * (2.46 * 10**4 * T + 1.57 * 100 * T**2 + 2 * T**3)**(1/3) * math.e**(-52.33 / T) * r**(2/3) / n**(2/3) * T_e**(4/15)

import math
r = 1
T = 5.78
# flux(20, 50)
print("recomb 10 and 50: ", recomb_rate(10), recomb_rate(50))
print("flux lower and upper: ", flux(7, 10), flux(10, 50))

# %%
stromgren(50, 10, 20, 1)
# Out:
# 365.33085839448114

# %%
# Out:
# 4.641588833612778

# %%
N = 50  

r_values = np.linspace(7, 10, N)
T_values = np.linspace(10, 50, N)

r, T = np.meshgrid(r_values, T_values)
# S_values = []
# for i in range(N):
#     S_values.append(flux(20))

S_values = []
for i in range(N):
    temp = []
    for j in range(N):
        temp.append(flux(r_values[i], T_values[j]))
    S_values.append(temp)

n_values = []
n_row = np.linspace(1000, 1100, N)
for k in range(N):
    n_values.append(n_row)

# S, n = np.meshgrid(x_values, y_values)
n = np.array(n_values)
S = np.array(S_values)
print("shapes: ", S.shape, n.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2ba6f4f9f8dc> in <module>()
#       1 N = 50
#       2
# ----> 3 r_values = np.linspace(7, 10, N)
#       4 T_values = np.linspace(10, 50, N)
#       5
#
# NameError: name 'np' is not defined

# %%
n
# Out:
# array([[1000.        , 1002.04081633, 1004.08163265, ..., 1095.91836735,
#         1097.95918367, 1100.        ],
#        [1000.        , 1002.04081633, 1004.08163265, ..., 1095.91836735,
#         1097.95918367, 1100.        ],
#        [1000.        , 1002.04081633, 1004.08163265, ..., 1095.91836735,
#         1097.95918367, 1100.        ],
#        ...,
#        [1000.        , 1002.04081633, 1004.08163265, ..., 1095.91836735,
#         1097.95918367, 1100.        ],
#        [1000.        , 1002.04081633, 1004.08163265, ..., 1095.91836735,
#         1097.95918367, 1100.        ],
#        [1000.        , 1002.04081633, 1004.08163265, ..., 1095.91836735,
#         1097.95918367, 1100.        ]])

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

fig = plt.figure()

R = stromgren(T, 10**4, r, n)
print("shape: ", R.shape, R)
ax = plt.axes(projection='3d')
# n = n*-1
ax.plot_surface(S, n, R);

# check for LISM density around A stars
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# shape:  (50, 50) [[ 0.09053797  0.09094143  0.09134237 ...  0.10715508  0.10746404
#    0.10777142]
#  [ 0.13822921  0.1388452   0.13945733 ...  0.16359946  0.16407117
#    0.16454045]
#  [ 0.19928647  0.20017455  0.20105707 ...  0.23586302  0.23654308
#    0.23721966]
#  ...
#  [10.87259188 10.92104335 10.96919127 ... 12.86812025 12.9052231
#   12.94213532]
#  [11.16037664 11.21011056 11.25953289 ... 13.20872429 13.24680922
#   13.28469846]
#  [11.44805534 11.49907124 11.54976753 ... 13.54920283 13.58826946
#   13.62713537]]

# %%
# import math
# R = []
# S = [7.92 * 10**34, 1.25 * 10**35, 1.25 * 10**36, 1.25 * 10**37, 1.25 * 10**38, 1.25 * 10**39, 1.25 * 10**40, 1.25 * 10**41, 1.25 * 10**42, 1.25 * 10**43, 1.25 * 10**44, 1.25 * 10**45, 1.25 * 10**46, 1.25 * 10**47, 1.25 * 10**48, 1.25 * 10**49]
# n = [0.095, 0.822, 1.549, 2.276, 3.003, 3.73, 4.457, 5.184, 5.911, 6.638, 7.365, 8.092, 8.819, 9.546, 10.273, 11]
# beta = 8.2 * 10**-14

# for i in range(len(S)):
#     R.append(((3 * S[i]) / (4 * math.pi * n[i]**2 * beta))**(1/3))
# print(R)
# Out:
# [2.9452703798121748e+16, 8136194187842127.0, 1.1489511705527784e+16, 1.915230335560398e+16, 3.430038243779175e+16, 6.395334960346112e+16, 1.2236036422189762e+17, 2.3835587187469584e+17, 4.7050243734005856e+17, 9.382336789799647e+17, 1.886053536916795e+18, 3.816207092744687e+18, 7.763477321756881e+18, 1.5865541415204446e+19, 3.2549000602998407e+19, 6.699988547296862e+19]

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
# surface rather than line plot
# for radius of star and temperature of star

fig = plt.figure()
ax = plt.axes(projection='3d')

# S = 1.25⋅10**49

# R = ((3 * S) / (4 * math.pi * n**2 * beta))**(1/3)

ax.plot_surface(n, S, R, 'gray')
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-d814ece8aad0> in <module>()
#      17 # S = np.sin(R)
#      18 # n = np.cos(R)
# ---> 19 ax.plot_surface(n, S, R, 'gray')
#
# ~\Documents\Coding\anaconda3_5.2_x64\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1633         had_data = self.has_data()
#    1634
# -> 1635         if Z.ndim != 2:
#    1636             raise ValueError("Argument Z must be 2-dimensional.")
#    1637         # TODO: Support masked arrays
#
# AttributeError: 'list' object has no attribute 'ndim'

# %%
def function_z(x, y):
    return 50 - (x**2 + y**2)

# %%
N = 50  

x_values = np.linspace(-5, 5, N)
y_values = np.linspace(-5, 5, N)

X, Y = np.meshgrid(x_values, y_values)

print("shapes: ", x_values.shape, Y.shape)
x_values
# Out:
# shapes:  (50,) (50, 50)
# array([-5.        , -4.79591837, -4.59183673, -4.3877551 , -4.18367347,
#        -3.97959184, -3.7755102 , -3.57142857, -3.36734694, -3.16326531,
#        -2.95918367, -2.75510204, -2.55102041, -2.34693878, -2.14285714,
#        -1.93877551, -1.73469388, -1.53061224, -1.32653061, -1.12244898,
#        -0.91836735, -0.71428571, -0.51020408, -0.30612245, -0.10204082,
#         0.10204082,  0.30612245,  0.51020408,  0.71428571,  0.91836735,
#         1.12244898,  1.32653061,  1.53061224,  1.73469388,  1.93877551,
#         2.14285714,  2.34693878,  2.55102041,  2.75510204,  2.95918367,
#         3.16326531,  3.36734694,  3.57142857,  3.7755102 ,  3.97959184,
#         4.18367347,  4.3877551 ,  4.59183673,  4.79591837,  5.        ])

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# fig = plt.figure()

Z = function_z(X, Y)
print("shape: ", Z.shape)
# ax = plt.axes(projection='3d')
# ax.plot_surface(X, Y, Z);
# Out:
# shape:  (50, 50)
